# %%
import pandas as pd

# %% [markdown]
# Read the dataset

# %%
df = pd.read_csv(r"C:\Dataset\Video Game Sales\vgsales.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# Filtering columns & rows

# %%
df[df['Rank'] <= 10]
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
specific_platform = ['Wii', ['NES']]
df[df['Platform'].isin(specific_platform)]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df[df['Name'].str.contains('Wii')]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 13        14                                            Wii Fit      Wii
# 14        15                                       Wii Fit Plus      Wii
# 78        79                                          Wii Party      Wii
# 97        98                Super Smash Bros. for Wii U and 3DS      3DS
# 203      204                Super Smash Bros. for Wii U and 3DS     WiiU
# 320      321                      Big Brain Academy: Wii Degree      Wii
# 412      413                                          Wii Music      Wii
# ...

# %% [markdown]
# Setting column as index

# %%
df2 = df.set_index('Platform')
df2
# Out:
#            Rank                                              Name    Year  \
# Platform
# Wii           1                                        Wii Sports  2006.0
# NES           2                                 Super Mario Bros.  1985.0
# Wii           3                                    Mario Kart Wii  2008.0
# Wii           4                                 Wii Sports Resort  2009.0
# GB            5                          Pokemon Red/Pokemon Blue  1996.0
# ...         ...                                               ...     ...
# GBA       16596                Woody Woodpecker in Crazy Castle 5  2002.0
# GC        16597                     Men in Black II: Alien Escape  2003.0
# PS2       16598  SCORE International Baja 1000: The Official Game  2008.0
# DS        16599                                        Know How 2  2010.0
# GBA       16600                                  Spirits & Spells  2003.0
#
# ...

# %%
df2.filter(items = ['Name', 'Genre'])
# Out:
#                                                       Name         Genre
# Platform
# Wii                                             Wii Sports        Sports
# NES                                      Super Mario Bros.      Platform
# Wii                                         Mario Kart Wii        Racing
# Wii                                      Wii Sports Resort        Sports
# GB                                Pokemon Red/Pokemon Blue  Role-Playing
# ...                                                    ...           ...
# GBA                     Woody Woodpecker in Crazy Castle 5      Platform
# GC                           Men in Black II: Alien Escape       Shooter
# PS2       SCORE International Baja 1000: The Official Game        Racing
# DS                                              Know How 2        Puzzle
# GBA                                       Spirits & Spells      Platform
#
# [16598 rows x 2 columns]

# %%
df2.filter(like = 'Wii', axis = 0)
# Out:
#            Rank                                               Name    Year  \
# Platform
# Wii           1                                         Wii Sports  2006.0
# Wii           3                                     Mario Kart Wii  2008.0
# Wii           4                                  Wii Sports Resort  2009.0
# Wii           8                                           Wii Play  2006.0
# Wii           9                          New Super Mario Bros. Wii  2009.0
# ...         ...                                                ...     ...
# Wii       16520                       Teenage Mutant Ninja Turtles  2007.0
# Wii       16555           Mahou Sensei Negima!? Neo-Pactio Fight!!  2007.0
# Wii       16576                                Mini Desktop Racing  2007.0
# Wii       16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...  2008.0
# Wii       16584                                          Fit & Fun  2011.0
#
# ...

# %% [markdown]
# filter the values by platform index

# %%
df2.loc['GBA']
# Out:
#            Rank                                     Name    Year  \
# Platform
# GBA          26            Pokemon Ruby/Pokemon Sapphire  2002.0
# GBA          59        Pokemon FireRed/Pokemon LeafGreen  2004.0
# GBA         131                  Pokémon Emerald Version  2004.0
# GBA         163                      Super Mario Advance  2001.0
# GBA         164                Mario Kart: Super Circuit  2001.0
# ...         ...                                      ...     ...
# GBA       16559  Super Robot Taisen: Original Generation  2002.0
# GBA       16566           Mortal Kombat: Deadly Alliance  2002.0
# GBA       16585                          Planet Monsters  2001.0
# GBA       16596       Woody Woodpecker in Crazy Castle 5  2002.0
# GBA       16600                         Spirits & Spells  2003.0
#
#                  Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# GBA       Role-Playing      Nintendo      6.06      3.90      5.38
# ...

# %% [markdown]
# filter the values by index

# %%
df2.iloc[3]
# Out:
# Rank                            4
# Name            Wii Sports Resort
# Year                       2009.0
# Genre                      Sports
# Publisher                Nintendo
# NA_Sales                    15.75
# EU_Sales                    11.01
# JP_Sales                     3.28
# Other_Sales                  2.96
# Global_Sales                 33.0
# Name: Wii, dtype: object

# %% [markdown]
# filtering using group by

# %%
df[df['Rank'] > 10].sort_values(by=['Rank'], ascending=[False])
# Out:
#         Rank                                              Name Platform  \
# 16597  16600                                  Spirits & Spells      GBA
# 16596  16599                                        Know How 2       DS
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# ...      ...                                               ...      ...
# 14        15                                      Wii Fit Plus      Wii
# 13        14                                           Wii Fit      Wii
# 12        13                       Pokemon Gold/Pokemon Silver       GB
# 11        12                                     Mario Kart DS       DS
# 10        11                                        Nintendogs       DS
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
