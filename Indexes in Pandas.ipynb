# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Dataset\Video Game Sales\vgsales.csv')

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# Set Platform as an index while reading the file

# %%
df = pd.read_csv(r'C:\Dataset\Video Game Sales\vgsales.csv', index_col= 'Platform')

df
# Out:
#            Rank                                              Name    Year  \
# Platform
# Wii           1                                        Wii Sports  2006.0
# NES           2                                 Super Mario Bros.  1985.0
# Wii           3                                    Mario Kart Wii  2008.0
# Wii           4                                 Wii Sports Resort  2009.0
# GB            5                          Pokemon Red/Pokemon Blue  1996.0
# ...         ...                                               ...     ...
# GBA       16596                Woody Woodpecker in Crazy Castle 5  2002.0
# GC        16597                     Men in Black II: Alien Escape  2003.0
# PS2       16598  SCORE International Baja 1000: The Official Game  2008.0
# DS        16599                                        Know How 2  2010.0
# GBA       16600                                  Spirits & Spells  2003.0
#
# ...

# %% [markdown]
# Reset to normal index

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       Platform   Rank                                              Name  \
# 0          Wii      1                                        Wii Sports
# 1          NES      2                                 Super Mario Bros.
# 2          Wii      3                                    Mario Kart Wii
# 3          Wii      4                                 Wii Sports Resort
# 4           GB      5                          Pokemon Red/Pokemon Blue
# ...        ...    ...                                               ...
# 16593      GBA  16596                Woody Woodpecker in Crazy Castle 5
# 16594       GC  16597                     Men in Black II: Alien Escape
# 16595      PS2  16598  SCORE International Baja 1000: The Official Game
# 16596       DS  16599                                        Know How 2
# 16597      GBA  16600                                  Spirits & Spells
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# Set an index after read the file

# %%
df.set_index('Name', inplace = True)

df
# Out:
#                                                  Platform   Rank    Year  \
# Name
# Wii Sports                                            Wii      1  2006.0
# Super Mario Bros.                                     NES      2  1985.0
# Mario Kart Wii                                        Wii      3  2008.0
# Wii Sports Resort                                     Wii      4  2009.0
# Pokemon Red/Pokemon Blue                               GB      5  1996.0
# ...                                                   ...    ...     ...
# Woody Woodpecker in Crazy Castle 5                    GBA  16596  2002.0
# Men in Black II: Alien Escape                          GC  16597  2003.0
# SCORE International Baja 1000: The Official Game      PS2  16598  2008.0
# Know How 2                                             DS  16599  2010.0
# Spirits & Spells                                      GBA  16600  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %% [markdown]
# Filter index by Name column

# %%
df.loc['Wii Sports']
# Out:
# Platform             Wii
# Rank                   1
# Year              2006.0
# Genre             Sports
# Publisher       Nintendo
# NA_Sales           41.49
# EU_Sales           29.02
# JP_Sales            3.77
# Other_Sales         8.46
# Global_Sales       82.74
# Name: Wii Sports, dtype: object

# %% [markdown]
# Filter index by index

# %%
df.iloc[1]
# Out:
# Platform             NES
# Rank                   2
# Year              1985.0
# Genre           Platform
# Publisher       Nintendo
# NA_Sales           29.08
# EU_Sales            3.58
# JP_Sales            6.81
# Other_Sales         0.77
# Global_Sales       40.24
# Name: Super Mario Bros., dtype: object

# %%
df.reset_index(inplace = True)

# %% [markdown]
# Setting 2 columns as index

# %%
df.set_index(['Publisher','Name'], inplace=True)

# %%
df.sort_index()

#pd.set_option('display.max.rows', 16599)
# Out:
#                                                                    Platform  \
# Publisher       Name
# 10TACLE Studios Boulder Dash: Rocks!                                     DS
#                 Panzer Tactics                                           DS
#                 Pirates: Legend of the Black Buccaneer                  PS2
# 1C Company      King's Bounty: Armored Princess                          PC
#                 Men of War: Assault Squad                                PC
# ...                                                                     ...
# NaN             Umineko no Naku Koro ni San: Shinjitsu to Genso...      PS3
#                 World of Tanks                                         X360
#                 Xia-Xia                                                  DS
#                 Yu Yu Hakusho: Dark Tournament                          PS2
#                 wwe Smackdown vs. Raw 2006                              PS2
#
# ...

# %%
df.loc['10TACLE Studios','Boulder Dash: Rocks!']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2772\4201478290.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc['10TACLE Studios','Boulder Dash: Rocks!']
#                                      Platform   Rank    Year   Genre  \
# Publisher       Name
# 10TACLE Studios Boulder Dash: Rocks!       DS  14132  2007.0  Puzzle
#
#                                       NA_Sales  EU_Sales  JP_Sales  \
# Publisher       Name
# 10TACLE Studios Boulder Dash: Rocks!       0.0      0.03       0.0
#
#                                       Other_Sales  Global_Sales
# Publisher       Name
# 10TACLE Studios Boulder Dash: Rocks!          0.0          0.03

# %%
df.iloc[1]
# Out:
# Platform             NES
# Rank                   2
# Year              1985.0
# Genre           Platform
# NA_Sales           29.08
# EU_Sales            3.58
# JP_Sales            6.81
# Other_Sales         0.77
# Global_Sales       40.24
# Name: (Nintendo, Super Mario Bros.), dtype: object
